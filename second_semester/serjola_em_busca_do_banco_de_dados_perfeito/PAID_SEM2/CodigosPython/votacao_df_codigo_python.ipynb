# %%
import pandas as pd

# %%
votacao_df = pd.read_csv('votacao_df.csv', encoding='latin1', sep=';')

# %%
votacao_df.head()
# Out:
#    ANO_ELEICAO  NR_TURNO SG_UF SG_UE             NM_UE  CD_MUNICIPIO  \
# 0         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 1         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 2         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 3         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 4         2022         1    DF    DF  DISTRITO FEDERAL         97012
#
#   NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_CARGO            DS_CARGO  NR_VOTAVEL  \
# 0     BRASÍLIA       19       246         8  DEPUTADO DISTRITAL       30100
# 1     BRASÍLIA       15       357         8  DEPUTADO DISTRITAL       30100
# 2     BRASÍLIA       15       357         6    DEPUTADO FEDERAL        1422
# 3     BRASÍLIA        2       180         6    DEPUTADO FEDERAL        1422
# 4     BRASÍLIA       20       184         8  DEPUTADO DISTRITAL       30100
#
#                        NM_VOTAVEL  NR_LOCAL_VOTACAO  SQ_CANDIDATO  QT_VOTOS
# ...

# %%
distrital = votacao_df.loc[ votacao_df.DS_CARGO == 'DEPUTADO DISTRITAL' ].reset_index(drop=True)

# %%
federal = votacao_df.loc[ votacao_df.DS_CARGO == 'DEPUTADO FEDERAL' ].reset_index(drop=True)

# %%
senador = votacao_df.loc[ votacao_df.DS_CARGO == 'SENADOR' ].reset_index(drop=True)

# %%
governador = votacao_df.loc[ votacao_df.DS_CARGO == 'GOVERNADOR' ].reset_index(drop=True)

# %%
distrital.head()
# Out:
#    ANO_ELEICAO  NR_TURNO SG_UF SG_UE             NM_UE  CD_MUNICIPIO  \
# 0         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 1         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 2         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 3         2022         1    DF    DF  DISTRITO FEDERAL         97012
# 4         2022         1    DF    DF  DISTRITO FEDERAL         97012
#
#   NM_MUNICIPIO  NR_ZONA  NR_SECAO  CD_CARGO            DS_CARGO  NR_VOTAVEL  \
# 0     BRASÍLIA       19       246         8  DEPUTADO DISTRITAL       30100
# 1     BRASÍLIA       15       357         8  DEPUTADO DISTRITAL       30100
# 2     BRASÍLIA       20       184         8  DEPUTADO DISTRITAL       30100
# 3     BRASÍLIA       17       280         8  DEPUTADO DISTRITAL       30100
# 4     BRASÍLIA       15       414         8  DEPUTADO DISTRITAL       30100
#
#                      NM_VOTAVEL  NR_LOCAL_VOTACAO  SQ_CANDIDATO  QT_VOTOS
# ...

# %%
distrital[['QT_VOTOS', 'NM_VOTAVEL', 'NR_ZONA']].groupby(['NM_VOTAVEL', 'NR_ZONA'] ).sum().sort_values('QT_VOTOS', ascending=False).reset_index().head(30)
# Out:
#                                 NM_VOTAVEL  NR_ZONA  QT_VOTOS
# 0   BERNARDO ROGÉRIO MATA DE ARAÚJO JUNIOR       18     16429
# 1                  PEDRO PAULO DE OLIVEIRA        6     11970
# 2                JAQUELINE ANGELA DA SILVA        4     11686
# 3         CARLOS DALVAN SOARES DE OLIVEIRA       21     11056
# 4            FRANCISCO CLAUDIO DE ABRANTES        6     10667
# 5     JANE KLEBIA DO NASCIMENTO SILVA REIS        2     10391
# 6                 DANIEL DE SOUSA OLIVEIRA        4      9232
# 7                    DANIEL XAVIER DONIZET       17      8484
# 8            JOÃO HERMETO DE OLIVEIRA NETO       10      8386
# 9                       JOAO ALVES CARDOSO        5      8080
# 10                    FÁBIO FELIX SILVEIRA       14      7232
# 11                             VOTO BRANCO       16      6881
# 12                IOLANDO ALMEIDA DE SOUZA       16      6742
# 13                             VOTO BRANCO        8      6521
# ...

# %%
distrital[['QT_VOTOS', 'NM_VOTAVEL']].groupby(['NM_VOTAVEL'] ).sum().sort_values('QT_VOTOS', ascending=False).reset_index().head(30)
# Out:
#                                 NM_VOTAVEL  QT_VOTOS
# 0                              VOTO BRANCO     88490
# 1                     FÁBIO FELIX SILVEIRA     51792
# 2                                VOTO NULO     47561
# 3            FRANCISCO DOMINGOS DOS SANTOS     43854
# 4                    MAX MACIEL CAVALCANTI     35758
# 5                    DANIEL XAVIER DONIZET     33573
# 6                   MARCOS MARTINS MACHADO     31993
# 7      ROBÉRIO BANDEIRA DE NEGREIROS FILHO     31341
# 8                     JORGE VIANA DE SOUSA     30640
# 9                JAQUELINE ANGELA DA SILVA     26452
# 10       THIAGO DE ARAÚJO MACIEIRA MANZONI     25554
# 11        RODRIGO GERMANO DELMASSO MARTINS     23243
# 12                   EDUARDO WEYNE PEDROSA     22489
# 13             JOAQUIM DOMINGOS RORIZ NETO     21057
# 14                IOLANDO ALMEIDA DE SOUZA     20757
# 15                  DANIEL DE CASTRO SOUSA     20402
# 16           JOÃO HERMETO DE OLIVEIRA NETO     20332
# ...

# %%
federal[['QT_VOTOS', 'NM_VOTAVEL', 'NR_ZONA']].groupby(['NM_VOTAVEL', 'NR_ZONA'] ).sum().sort_values('QT_VOTOS', ascending=False).reset_index().head(30)
# Out:
#                            NM_VOTAVEL  NR_ZONA  QT_VOTOS
# 0     BEATRIZ KICIS TORRENTS DE SORDI       15     21329
# 1     BEATRIZ KICIS TORRENTS DE SORDI       14     17334
# 2          RAFAEL CAVALCANTI PRUDENTE        6     17221
# 3   DAVYS FREDERICO TEIXEIRA LINHARES       13     16804
# 4     BEATRIZ KICIS TORRENTS DE SORDI       18     15576
# 5          RAFAEL CAVALCANTI PRUDENTE        5     13822
# 6   DAVYS FREDERICO TEIXEIRA LINHARES       21     13725
# 7     BEATRIZ KICIS TORRENTS DE SORDI        9     13657
# 8   DAVYS FREDERICO TEIXEIRA LINHARES       16     13445
# 9     BEATRIZ KICIS TORRENTS DE SORDI        5     13222
# 10  DAVYS FREDERICO TEIXEIRA LINHARES        4     13144
# 11    BEATRIZ KICIS TORRENTS DE SORDI        1     12932
# 12    BEATRIZ KICIS TORRENTS DE SORDI       19     12680
# 13                   ERIKA JUCÁ KOKAY       15     12507
# 14  DAVYS FREDERICO TEIXEIRA LINHARES        8     12470
# ...

# %%
senador[['QT_VOTOS', 'NM_VOTAVEL', 'NR_ZONA']].groupby(['NM_VOTAVEL', 'NR_ZONA'] ).sum().sort_values('QT_VOTOS', ascending=False).reset_index().head(30)
# Out:
#                NM_VOTAVEL  NR_ZONA  QT_VOTOS
# 0    DAMARES REGINA ALVES       15     56488
# 1    DAMARES REGINA ALVES       13     46169
# 2    DAMARES REGINA ALVES       16     45862
# 3    DAMARES REGINA ALVES        8     43393
# 4    DAMARES REGINA ALVES        9     43220
# 5    DAMARES REGINA ALVES        5     43178
# 6    DAMARES REGINA ALVES       10     43117
# 7    DAMARES REGINA ALVES       17     41712
# 8    DAMARES REGINA ALVES       18     40829
# 9    DAMARES REGINA ALVES        6     39584
# 10   DAMARES REGINA ALVES       19     37973
# 11  FLÁVIA CAROLINA PÉRES       16     36264
# 12   DAMARES REGINA ALVES       21     34851
# 13   DAMARES REGINA ALVES        2     33726
# 14   DAMARES REGINA ALVES        4     32714
# 15   DAMARES REGINA ALVES       14     31595
# 16  FLÁVIA CAROLINA PÉRES        6     31265
# 17  FLÁVIA CAROLINA PÉRES       13     30631
# 18   ROSILENE CORRÊA LIMA       15     28833
# 19  FLÁVIA CAROLINA PÉRES        8     27641
# ...

# %%
senador[['QT_VOTOS', 'NM_VOTAVEL']].groupby(['NM_VOTAVEL'] ).sum().sort_values('QT_VOTOS', ascending=False).reset_index().head(30)
# Out:
#                         NM_VOTAVEL  QT_VOTOS
# 0             DAMARES REGINA ALVES    714562
# 1            FLÁVIA CAROLINA PÉRES    429676
# 2             ROSILENE CORRÊA LIMA    356198
# 3                      VOTO BRANCO    119075
# 4                        VOTO NULO     99697
# 5            JOE CARLO VIANA VALLE     49310
# 6        YARA MARISTELA PRADO LOBO      9676
# 7   CARLOS DIVINO VIEIRA RODRIGUES      9366
# 8       PEDRO IVO DE SOUZA BATISTA      8133
# 9     JOSE GABRIEL DE SOUZA JUNIOR      4795
# 10       ELCIMARA AUGUSTO DE SOUZA      2473
# 11        HÉLIO JOSÉ DA SILVA LIMA      2069
# 12      MARCELO ABRUNHOSA HIPÓLITO      1841
# 13   EXPEDITO CARNEIRO DE MENDONÇA       613

# %%
desempenho_senador = senador[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()


desempenho_senador['Porcentagem do Total'] = desempenho_senador.QT_VOTOS / (desempenho_senador.QT_VOTOS.sum()) * 100
desempenho_senador['Soma Acumuluda'] = desempenho_senador.QT_VOTOS.cumsum()
desempenho_senador['Portentagem Acumuluda'] = desempenho_senador['Porcentagem do Total'].cumsum()
desempenho_senador.head(30)
# Out:
#                         NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0             DAMARES REGINA ALVES    714562             39.533517
# 1            FLÁVIA CAROLINA PÉRES    429676             23.772050
# 2             ROSILENE CORRÊA LIMA    356198             19.706841
# 3                      VOTO BRANCO    119075              6.587887
# 4                        VOTO NULO     99697              5.515789
# 5            JOE CARLO VIANA VALLE     49310              2.728102
# 6        YARA MARISTELA PRADO LOBO      9676              0.535330
# 7   CARLOS DIVINO VIEIRA RODRIGUES      9366              0.518179
# 8       PEDRO IVO DE SOUZA BATISTA      8133              0.449962
# 9     JOSE GABRIEL DE SOUZA JUNIOR      4795              0.265286
# 10       ELCIMARA AUGUSTO DE SOUZA      2473              0.136820
# 11        HÉLIO JOSÉ DA SILVA LIMA      2069              0.114469
# 12      MARCELO ABRUNHOSA HIPÓLITO      1841              0.101854
# ...

# %%
governador[['QT_VOTOS', 'NM_VOTAVEL', 'NR_ZONA']].groupby(['NM_VOTAVEL', 'NR_ZONA'] ).sum().sort_values('QT_VOTOS', ascending=False).reset_index().head(30)
# Out:
#                        NM_VOTAVEL  NR_ZONA  QT_VOTOS
# 0     IBANEIS ROCHA BARROS JÚNIOR       16     60497
# 1     IBANEIS ROCHA BARROS JÚNIOR       15     60443
# 2     IBANEIS ROCHA BARROS JÚNIOR       13     59785
# 3     IBANEIS ROCHA BARROS JÚNIOR        6     52401
# 4     IBANEIS ROCHA BARROS JÚNIOR        8     52204
# 5     IBANEIS ROCHA BARROS JÚNIOR       21     51696
# 6     IBANEIS ROCHA BARROS JÚNIOR       10     50045
# 7     IBANEIS ROCHA BARROS JÚNIOR        5     49575
# 8     IBANEIS ROCHA BARROS JÚNIOR        9     46059
# 9     IBANEIS ROCHA BARROS JÚNIOR       18     45294
# 10    IBANEIS ROCHA BARROS JÚNIOR       19     44439
# 11    IBANEIS ROCHA BARROS JÚNIOR        2     44243
# 12    IBANEIS ROCHA BARROS JÚNIOR       17     43455
# 13    IBANEIS ROCHA BARROS JÚNIOR        4     37772
# 14  LEANDRO ANTÔNIO GRASS PEIXOTO       15     36224
# 15  LEANDRO ANTÔNIO GRASS PEIXOTO       14     32793
# 16    IBANEIS ROCHA BARROS JÚNIOR       20     30699
# ...

# %%
governador[['QT_VOTOS', 'NM_VOTAVEL']].groupby(['NM_VOTAVEL'] ).sum().sort_values('QT_VOTOS', ascending=False).reset_index().head(30)
# Out:
#                           NM_VOTAVEL  QT_VOTOS
# 0        IBANEIS ROCHA BARROS JÚNIOR    832633
# 1      LEANDRO ANTÔNIO GRASS PEIXOTO    434587
# 2        PAULO OCTÁVIO ALVES PEREIRA    123715
# 3        ELZIOVAN MATIAS MORENO LIMA     94100
# 4                          VOTO NULO     86099
# 5         LEILA GOMES DE BARROS RÊGO     79597
# 6              IZALCI LUCAS FERREIRA     70584
# 7                        VOTO BRANCO     65969
# 8   CLEMENTINA ARAÚJO BAGNO DA SILVA     13613
# 9           LUIZ CARLOS LUCAS SALLES      4218
# 10     TEODORO ANTONIO DA CRUZ FILHO      1155
# 11          ROBSON RAYMUNDO DA SILVA       841
# 12              RENAN ROSA DE ARRUDA       373

# %%
governador_zona1 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona1['Porcentagem do Total'] = governador_zona1.QT_VOTOS / (governador_zona1.QT_VOTOS.sum()) * 100
governador_zona1['Soma Acumuluda'] = governador_zona1.QT_VOTOS.cumsum()
governador_zona1['Portentagem Acumuluda'] = governador_zona1['Porcentagem do Total'].cumsum()
display(governador_zona1.head(13))

governador_zona2 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 2].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona2['Porcentagem do Total'] = governador_zona2.QT_VOTOS / (governador_zona2.QT_VOTOS.sum()) * 100
governador_zona2['Soma Acumuluda'] = governador_zona2.QT_VOTOS.cumsum()
governador_zona2['Portentagem Acumuluda'] = governador_zona2['Porcentagem do Total'].cumsum()
display(governador_zona2.head(13)
        )
governador_zona3 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 3].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona3['Porcentagem do Total'] = governador_zona3.QT_VOTOS / (governador_zona3.QT_VOTOS.sum()) * 100
governador_zona3['Soma Acumuluda'] = governador_zona3.QT_VOTOS.cumsum()
governador_zona3['Portentagem Acumuluda'] = governador_zona3['Porcentagem do Total'].cumsum()
display(governador_zona3.head(13))

governador_zona4 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 4].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona4['Porcentagem do Total'] = governador_zona4.QT_VOTOS / (governador_zona4.QT_VOTOS.sum()) * 100
governador_zona4['Soma Acumuluda'] = governador_zona4.QT_VOTOS.cumsum()
governador_zona4['Portentagem Acumuluda'] = governador_zona4['Porcentagem do Total'].cumsum()
display(governador_zona4.head(13))

governador_zona5 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 5].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona5['Porcentagem do Total'] = governador_zona5.QT_VOTOS / (governador_zona5.QT_VOTOS.sum()) * 100
governador_zona5['Soma Acumuluda'] = governador_zona5.QT_VOTOS.cumsum()
governador_zona5['Portentagem Acumuluda'] = governador_zona5['Porcentagem do Total'].cumsum()
display(governador_zona5.head(13))

governador_zona6 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 6].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona6['Porcentagem do Total'] = governador_zona6.QT_VOTOS / (governador_zona6.QT_VOTOS.sum()) * 100
governador_zona6['Soma Acumuluda'] = governador_zona6.QT_VOTOS.cumsum()
governador_zona6['Portentagem Acumuluda'] = governador_zona6['Porcentagem do Total'].cumsum()
display(governador_zona6.head(13))

governador_zona8 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 8].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona8['Porcentagem do Total'] = governador_zona8.QT_VOTOS / (governador_zona8.QT_VOTOS.sum()) * 100
governador_zona8['Soma Acumuluda'] = governador_zona8.QT_VOTOS.cumsum()
governador_zona8['Portentagem Acumuluda'] = governador_zona8['Porcentagem do Total'].cumsum()
display(governador_zona8.head(13))

governador_zona9 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 9].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona9['Porcentagem do Total'] = governador_zona9.QT_VOTOS / (governador_zona9.QT_VOTOS.sum()) * 100
governador_zona9['Soma Acumuluda'] = governador_zona9.QT_VOTOS.cumsum()
governador_zona9['Portentagem Acumuluda'] = governador_zona9['Porcentagem do Total'].cumsum()
display(governador_zona9.head(13))

governador_zona10 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 10].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona10['Porcentagem do Total'] = governador_zona10.QT_VOTOS / (governador_zona10.QT_VOTOS.sum()) * 100
governador_zona10['Soma Acumuluda'] = governador_zona10.QT_VOTOS.cumsum()
governador_zona10['Portentagem Acumuluda'] = governador_zona10['Porcentagem do Total'].cumsum()
display(governador_zona10.head(13))

governador_zona11 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 11].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona11['Porcentagem do Total'] = governador_zona11.QT_VOTOS / (governador_zona11.QT_VOTOS.sum()) * 100
governador_zona11['Soma Acumuluda'] = governador_zona11.QT_VOTOS.cumsum()
governador_zona11['Portentagem Acumuluda'] = governador_zona11['Porcentagem do Total'].cumsum()
display(governador_zona11.head(13))

# governador_zona12 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

# governador_zona12['Porcentagem do Total'] = governador_zona12.QT_VOTOS / (governador_zona12.QT_VOTOS.sum()) * 100
# governador_zona12['Soma Acumuluda'] = governador_zona12.QT_VOTOS.cumsum()
# governador_zona12['Portentagem Acumuluda'] = governador_zona12['Porcentagem do Total'].cumsum()
# display(governador_zona12.head(13))

governador_zona13 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 13].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona13['Porcentagem do Total'] = governador_zona13.QT_VOTOS / (governador_zona13.QT_VOTOS.sum()) * 100
governador_zona13['Soma Acumuluda'] = governador_zona13.QT_VOTOS.cumsum()
governador_zona13['Portentagem Acumuluda'] = governador_zona13['Porcentagem do Total'].cumsum()
display(governador_zona13.head(13))

governador_zona14 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 14].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona14['Porcentagem do Total'] = governador_zona14.QT_VOTOS / (governador_zona14.QT_VOTOS.sum()) * 100
governador_zona14['Soma Acumuluda'] = governador_zona14.QT_VOTOS.cumsum()
governador_zona14['Portentagem Acumuluda'] = governador_zona14['Porcentagem do Total'].cumsum()
display(governador_zona14.head(13))

governador_zona15 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 15].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona15['Porcentagem do Total'] = governador_zona15.QT_VOTOS / (governador_zona15.QT_VOTOS.sum()) * 100
governador_zona15['Soma Acumuluda'] = governador_zona15.QT_VOTOS.cumsum()
governador_zona15['Portentagem Acumuluda'] = governador_zona15['Porcentagem do Total'].cumsum()
display(governador_zona15.head(13))

governador_zona16 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 16].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona16['Porcentagem do Total'] = governador_zona16.QT_VOTOS / (governador_zona16.QT_VOTOS.sum()) * 100
governador_zona16['Soma Acumuluda'] = governador_zona16.QT_VOTOS.cumsum()
governador_zona16['Portentagem Acumuluda'] = governador_zona16['Porcentagem do Total'].cumsum()
display(governador_zona16.head(13))

governador_zona17 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 17].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona17['Porcentagem do Total'] = governador_zona17.QT_VOTOS / (governador_zona17.QT_VOTOS.sum()) * 100
governador_zona17['Soma Acumuluda'] = governador_zona17.QT_VOTOS.cumsum()
governador_zona17['Portentagem Acumuluda'] = governador_zona17['Porcentagem do Total'].cumsum()
display(governador_zona17.head(13))

governador_zona18 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 18].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona18['Porcentagem do Total'] = governador_zona18.QT_VOTOS / (governador_zona18.QT_VOTOS.sum()) * 100
governador_zona18['Soma Acumuluda'] = governador_zona18.QT_VOTOS.cumsum()
governador_zona18['Portentagem Acumuluda'] = governador_zona18['Porcentagem do Total'].cumsum()
display(governador_zona18.head(13))

governador_zona19 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 19].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona19['Porcentagem do Total'] = governador_zona19.QT_VOTOS / (governador_zona19.QT_VOTOS.sum()) * 100
governador_zona19['Soma Acumuluda'] = governador_zona19.QT_VOTOS.cumsum()
governador_zona19['Portentagem Acumuluda'] = governador_zona19['Porcentagem do Total'].cumsum()
display(governador_zona19.head(13))

governador_zona20 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 20].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona20['Porcentagem do Total'] = governador_zona20.QT_VOTOS / (governador_zona20.QT_VOTOS.sum()) * 100
governador_zona20['Soma Acumuluda'] = governador_zona20.QT_VOTOS.cumsum()
governador_zona20['Portentagem Acumuluda'] = governador_zona20['Porcentagem do Total'].cumsum()
display(governador_zona20.head(13))

governador_zona21 = governador[['NM_VOTAVEL', 'QT_VOTOS']].loc[governador.NR_ZONA == 21].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

governador_zona21['Porcentagem do Total'] = governador_zona21.QT_VOTOS / (governador_zona21.QT_VOTOS.sum()) * 100
governador_zona21['Soma Acumuluda'] = governador_zona21.QT_VOTOS.cumsum()
governador_zona21['Portentagem Acumuluda'] = governador_zona21['Porcentagem do Total'].cumsum()
display(governador_zona21.head(13))
# Out:
#                           NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0        IBANEIS ROCHA BARROS JÚNIOR     22367             36.133503
# 1      LEANDRO ANTÔNIO GRASS PEIXOTO     21370             34.522867
# 2        ELZIOVAN MATIAS MORENO LIMA      5556              8.975622
# 3        PAULO OCTÁVIO ALVES PEREIRA      3406              5.502334
# 4         LEILA GOMES DE BARROS RÊGO      2498              4.035476
# 5                          VOTO NULO      2060              3.327895
# 6              IZALCI LUCAS FERREIRA      1991              3.216426
# 7                        VOTO BRANCO      1596              2.578311
# 8   CLEMENTINA ARAÚJO BAGNO DA SILVA       786              1.269769
# 9           LUIZ CARLOS LUCAS SALLES       157              0.253631
# 10     TEODORO ANTONIO DA CRUZ FILHO        57              0.092083
# 11          ROBSON RAYMUNDO DA SILVA        37              0.059773
# 12              RENAN ROSA DE ARRUDA        20              0.032310
#
# ...

# %%
governador_zona14.head(13)
# Out:
#                           NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0      LEANDRO ANTÔNIO GRASS PEIXOTO     32793             37.660637
# 1        IBANEIS ROCHA BARROS JÚNIOR     28781             33.053115
# 2        ELZIOVAN MATIAS MORENO LIMA      7601              8.729256
# 3        PAULO OCTÁVIO ALVES PEREIRA      4163              4.780936
# 4         LEILA GOMES DE BARROS RÊGO      3961              4.548952
# 5                          VOTO NULO      2716              3.119150
# 6              IZALCI LUCAS FERREIRA      2705              3.106517
# 7                        VOTO BRANCO      2439              2.801034
# 8   CLEMENTINA ARAÚJO BAGNO DA SILVA      1458              1.674419
# 9           LUIZ CARLOS LUCAS SALLES       276              0.316968
# 10     TEODORO ANTONIO DA CRUZ FILHO        83              0.095320
# 11          ROBSON RAYMUNDO DA SILVA        58              0.066609
# 12              RENAN ROSA DE ARRUDA        41              0.047086
#
# ...

# %%
desempenho_governador = governador[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

# %%
desempenho_governador['Porcentagem do Total'] = desempenho_governador.QT_VOTOS / (desempenho_governador.QT_VOTOS.sum()) * 100
desempenho_governador['Soma Acumuluda'] = desempenho_governador.QT_VOTOS.cumsum()
desempenho_governador['Portentagem Acumuluda'] = desempenho_governador['Porcentagem do Total'].cumsum()
desempenho_governador.head(30)
# Out:
#                           NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0        IBANEIS ROCHA BARROS JÚNIOR    832633             46.065857
# 1      LEANDRO ANTÔNIO GRASS PEIXOTO    434587             24.043754
# 2        PAULO OCTÁVIO ALVES PEREIRA    123715              6.844597
# 3        ELZIOVAN MATIAS MORENO LIMA     94100              5.206132
# 4                          VOTO NULO     86099              4.763472
# 5         LEILA GOMES DE BARROS RÊGO     79597              4.403746
# 6              IZALCI LUCAS FERREIRA     70584              3.905097
# 7                        VOTO BRANCO     65969              3.649770
# 8   CLEMENTINA ARAÚJO BAGNO DA SILVA     13613              0.753146
# 9           LUIZ CARLOS LUCAS SALLES      4218              0.233363
# 10     TEODORO ANTONIO DA CRUZ FILHO      1155              0.063901
# 11          ROBSON RAYMUNDO DA SILVA       841              0.046529
# 12              RENAN ROSA DE ARRUDA       373              0.020636
#
# ...

# %%
desempenho_federal = federal[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()


desempenho_federal['Porcentagem do Total'] = desempenho_federal.QT_VOTOS / (desempenho_federal.QT_VOTOS.sum()) * 100
desempenho_federal['Soma Acumuluda'] = desempenho_federal.QT_VOTOS.cumsum()
desempenho_federal['Portentagem Acumuluda'] = desempenho_federal['Porcentagem do Total'].cumsum()
desempenho_federal.head(60)
# Out:
#                                         NM_VOTAVEL  QT_VOTOS  \
# 0                  BEATRIZ KICIS TORRENTS DE SORDI    214733
# 1                DAVYS FREDERICO TEIXEIRA LINHARES    165358
# 2                                 ERIKA JUCÁ KOKAY    146092
# 3                       RAFAEL CAVALCANTI PRUDENTE    121307
# 4                                      VOTO BRANCO    114654
# 5                              JULIO CESAR RIBEIRO     76274
# 6                                        VOTO NULO     56923
# 7                           REGINALDO VERAS COELHO     54557
# 8                        RODRIGO SOBRAL ROLLEMBERG     51926
# 9                               RONEY TANIOS NEMER     46151
# 10                            ISRAEL MATOS BATISTA     40885
# 11                       ERIVAN HILÁRIO DOS SANTOS     31538
# 12                  MARCOS WESLEY DE SOUSA FEITOSA     29870
# 13                        JOÃO ALBERTO FRAGA SILVA     28825
# ...

# %%
desempenho_distrital = distrital[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()


desempenho_distrital['Porcentagem do Total'] = desempenho_distrital.QT_VOTOS / (desempenho_distrital.QT_VOTOS.sum()) * 100
desempenho_distrital['Soma Acumuluda'] = desempenho_distrital.QT_VOTOS.cumsum()
desempenho_distrital['Portentagem Acumuluda'] = desempenho_distrital['Porcentagem do Total'].cumsum()
desempenho_distrital.head(30)
# Out:
#                                 NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0                              VOTO BRANCO     88490              4.895756
# 1                     FÁBIO FELIX SILVEIRA     51792              2.865420
# 2                                VOTO NULO     47561              2.631337
# 3            FRANCISCO DOMINGOS DOS SANTOS     43854              2.426246
# 4                    MAX MACIEL CAVALCANTI     35758              1.978330
# 5                    DANIEL XAVIER DONIZET     33573              1.857444
# 6                   MARCOS MARTINS MACHADO     31993              1.770029
# 7      ROBÉRIO BANDEIRA DE NEGREIROS FILHO     31341              1.733957
# 8                     JORGE VIANA DE SOUSA     30640              1.695174
# 9                JAQUELINE ANGELA DA SILVA     26452              1.463471
# 10       THIAGO DE ARAÚJO MACIEIRA MANZONI     25554              1.413788
# ...
